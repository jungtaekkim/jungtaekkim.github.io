# %% [markdown]
# # MNIST

# %% [markdown]
# ### MNIST 데이터 받기

# %%
import os
import sys
from six.moves import urllib
import gzip
import pickle
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt


SOURCE_URL = 'http://www.iro.umontreal.ca/~lisa/deep/data/mnist/mnist.pkl.gz'
FILENAME = SOURCE_URL.split('/')[-1]
DATA_DIR = './datasets'

def maybe_download(data_dir):
    filepath = os.path.join(data_dir, FILENAME)
    if not os.path.exists(data_dir):
        os.makedirs(data_dir)
    if not os.path.isfile(filepath):
        def _progress(count, block_size, total_size):
            sys.stdout.write('\r>> Downloading {} {:.1f} %'.format(
                FILENAME, float(count * block_size) / float(total_size) * 100.0))
            sys.stdout.flush()
        filepath, _ = urllib.request.urlretrieve(SOURCE_URL, filepath, _progress)
        print()
        statinfo = os.stat(filepath)
        print('Successfully donloaded', FILENAME, statinfo.st_size, 'bytes.')

def load(data_dir, subset='train'):
    maybe_download(data_dir)
    filepath = os.path.join(data_dir, FILENAME)
    
    f = gzip.open(filepath, 'rb')
    u = pickle._Unpickler(f)
    u.encoding = 'latin1'
    train_set, valid_set, test_set = u.load()
    f.close()
    
    if subset == 'train':
        trainx, trainy = train_set
        trainx = trainx.astype(np.float32).reshape(trainx.shape[0], 28, 28)
        trainy = trainy.astype(np.uint8)
        return trainx, trainy
    elif subset == 'test':
        testx, testy = test_set
        testx = testx.astype(np.float32).reshape(testx.shape[0], 28, 28)
        testy = testy.astype(np.uint8)
        return testx, testy
    elif subset== 'valid':
        validx, validy = valid_set
        validx = validx.astype(np.float32).reshape(validx.shape[0], 28, 28)
        validy = validy.astype(np.uint8)
        return validx, validy
    else:
        raise NotImplementedError('subset should be train or valid or test')

# Load data
train_data, train_label = load(DATA_DIR, 'train')
valid_data, valid_label = load(DATA_DIR, 'valid')
test_data, test_label = load(DATA_DIR, 'test')

# concatenate train and valid data as train data
train_data = np.concatenate((train_data, valid_data))
train_label = np.concatenate((train_label, valid_label))

# %% [markdown]
# ### MNIST 데이터 확인 하기

# %%
# size of MNIST
print(train_data.shape)
print(train_label.shape)
print(test_data.shape)
print(test_label.shape)
# Out:
# (60000, 28, 28)
# (60000,)
# (10000, 28, 28)
# (10000,)

# %%
# show data
_, (ax1, ax2) = plt.subplots(1, 2)
sample_data = train_data[13]
ax1.imshow(sample_data, cmap=plt.cm.Greys);
ax2.hist(sample_data, bins=20, range=[0, 1]);

# %%
import tensorflow as tf
import random
import shutil

SUMMARY_DIR = './ResNet_summary'
TRAIN_DIR = SUMMARY_DIR + '/train'
TEST_DIR = SUMMARY_DIR + '/test'

if os.path.exists(SUMMARY_DIR):
    shutil.rmtree(SUMMARY_DIR)
if not os.path.exists(SUMMARY_DIR):
    os.makedirs(SUMMARY_DIR)
    os.makedirs(TRAIN_DIR)
    os.makedirs(TEST_DIR)

def get_next_batch(data, label, batch_size):
    n_data = data.shape[0]
    random_idx = random.sample(range(1, n_data), batch_size)
    
    batch_data = data[random_idx]
    batch_label = label[random_idx]
    return batch_data, batch_label

def get_one_hot(label):
    one_hot = np.zeros((label.shape[0], 10))
    one_hot[np.arange(label.shape[0]), label.astype(int)] = 1
    return one_hot

def fully_connected(inputs, out_channel, name='fc'):
    in_channel = inputs.get_shape().as_list()[1]
    w_shape = [in_channel, out_channel]
    b_shape = [out_channel]

    with tf.variable_scope(name):
        weights = tf.Variable(tf.truncated_normal(shape=w_shape, stddev=0.1), name='weights')
        biases = tf.Variable(tf.constant(0.1, shape=b_shape), name='biases')
        fc = tf.matmul(inputs, weights)
        fc = tf.nn.bias_add(fc, biases)

    return fc
    
def conv2d(inputs, filter_size, stride, out_channel, name='conv'):
    in_channel = inputs.get_shape().as_list()[3]
    w_shape = [filter_size, filter_size, in_channel, out_channel]
    b_shape = [out_channel]
    
    with tf.variable_scope(name):
        weights = tf.Variable(tf.truncated_normal(shape=w_shape, stddev=0.1), name='weights')
        biases = tf.Variable(tf.constant(0.1, shape=b_shape), name='biases')
        conv = tf.nn.conv2d(inputs, weights, strides=[1, stride, stride, 1], padding='SAME')
        conv = tf.nn.bias_add(conv, biases)
        
    return conv
    
def avg_pool_3x3(inputs):
    avg_pool = tf.nn.avg_pool(inputs, 
                              ksize=[1, 3, 3, 1], 
                              strides=[1, 2, 2, 1], 
                              padding='SAME', name='pool3x3')
    
    return avg_pool

def global_avg_pool(inputs):
    avg_pool = tf.reduce_mean(inputs, axis=[1, 2], name='glv_avg_pool')
    
    return avg_pool

def residual_block(inputs, output_channel, first_layer=False, name='resblk'):
    with tf.variable_scope(name):
        if first_layer:
            inputs_pool = avg_pool_3x3(inputs)
            identity = conv2d(inputs_pool, 1, 1, output_channel, name='pre_conv')
            conv1 = conv2d(inputs, 3, 2, output_channel, name='conv1')
        else:
            identity = inputs
            conv1 = conv2d(inputs, 3, 1, output_channel, name='conv1')
            
        conv1_relu = tf.nn.relu(conv1, name='conv1_relu')
        conv2 = conv2d(conv1_relu, 3, 1, output_channel, name='conv2')
        identity_mapping = tf.add(conv2, identity, name='identity_mapping')
        output = tf.nn.relu(identity_mapping, name='output_relu')
    return output
            
def get_cross_entropy_loss(y_true, y_hat, epsilon=1e-8):
    with tf.name_scope('cross_entropy'):
        cross_entropy = tf.reduce_mean(-tf.reduce_sum(y_true * tf.log(y_hat + epsilon), axis=[1]))
    return cross_entropy

def get_accuracy(y_true, y_hat):
    with tf.name_scope('accuracy'):
        correct_prediction = tf.equal(tf.argmax(y_hat, 1), tf.argmax(y_true, 1), name='correct_prediction')
        accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32), name='accuracy')
    return accuracy
            
learning_rate = 0.001
max_iter = 2000
batch_size = 100

train_label_hot = get_one_hot(train_label)
test_label_hot = get_one_hot(test_label)

x = tf.placeholder(tf.float32, [None, 28, 28], name='x')
y_true = tf.placeholder(tf.float32, [None, 10], name='y_true')
x_reshape = tf.reshape(x, [-1, 28, 28, 1], name='x_reshape')

with tf.name_scope('ResNet'):
    res1_1 = residual_block(x_reshape, 16, True, name='res1_1')
    res1_2 = residual_block(res1_1, 16, False, name='res1_2')
    res1_3 = residual_block(res1_2, 16, False, name='res1_3')

    res2_1 = residual_block(res1_3, 32, True, name='res2_1')
    res2_2 = residual_block(res2_1, 32, False, name='res2_2')
    res2_3 = residual_block(res2_2, 32, False, name='res2_3')

    res3_1 = residual_block(res2_3, 64, True, name='res3_1')
    res3_2 = residual_block(res3_1, 64, False, name='res3_2')
    res3_3 = residual_block(res3_2, 64, False, name='res3_3')

    glb_avg = global_avg_pool(res3_3)
    logit = fully_connected(glb_avg, 10, name='fc')
    y_hat = tf.nn.softmax(logit, name='y_hat')

cross_entropy = get_cross_entropy_loss(y_true, y_hat)
accuracy = get_accuracy(y_true, y_hat)
train_step = tf.train.AdamOptimizer(learning_rate).minimize(cross_entropy)

tf.summary.scalar('cross_entropy', cross_entropy)
tf.summary.scalar('accuracy', accuracy)
merged = tf.summary.merge_all()

init = tf.global_variables_initializer()

# %%
with tf.Session() as sess:
    train_writer = tf.summary.FileWriter(TRAIN_DIR, sess.graph)
    test_writer = tf.summary.FileWriter(TEST_DIR)
    
    sess.run(init)
    
    for step in range(max_iter):
        batch_x, batch_y = get_next_batch(train_data, train_label_hot, batch_size)
        _, loss, summary = sess.run([train_step, cross_entropy, merged], feed_dict={x: batch_x, y_true: batch_y})
        train_writer.add_summary(summary, step)
        acc, summary = sess.run([accuracy, merged], feed_dict={x: test_data, y_true: test_label_hot})
        test_writer.add_summary(summary, step)
        if (step + 1) % 10 == 0:
            print("{}th iteration, training loss: {:.4f}, test accuracy: {:.4f}".format(step + 1, loss, acc))
# Out:
# 10th iteration, training loss: 2.2779, test accuracy: 0.2394
# 20th iteration, training loss: 2.2346, test accuracy: 0.1302
# 30th iteration, training loss: 2.0889, test accuracy: 0.3021
# 40th iteration, training loss: 1.8966, test accuracy: 0.4968
# 50th iteration, training loss: 1.4173, test accuracy: 0.5166
# 60th iteration, training loss: 1.0367, test accuracy: 0.6552
# 70th iteration, training loss: 0.7635, test accuracy: 0.7551
# 80th iteration, training loss: 0.8496, test accuracy: 0.7980
# 90th iteration, training loss: 0.5698, test accuracy: 0.8456
# 100th iteration, training loss: 0.4598, test accuracy: 0.8483
# 110th iteration, training loss: 0.2827, test accuracy: 0.8615
# 120th iteration, training loss: 0.3760, test accuracy: 0.8943
# 130th iteration, training loss: 0.4520, test accuracy: 0.8907
# 140th iteration, training loss: 0.3468, test accuracy: 0.9219
# 150th iteration, training loss: 0.3369, test accuracy: 0.9129
# 160th iteration, training loss: 0.2111, test accuracy: 0.9296
# 170th iteration, training loss: 0.2605, test accuracy: 0.9260
# 180th iteration, training loss: 0.2666, test accuracy: 0.9182
# 190th iteration, training loss: 0.3848, test accuracy: 0.9176
# 200th iteration, training loss: 0.2485, test accuracy: 0.9349
# 210th iteration, training loss: 0.2065, test accuracy: 0.9330
# 220th iteration, training loss: 0.2343, test accuracy: 0.9400
# 230th iteration, training loss: 0.1649, test accuracy: 0.9391
# 240th iteration, training loss: 0.1196, test accuracy: 0.9496
# 250th iteration, training loss: 0.4867, test accuracy: 0.9414
# 260th iteration, training loss: 0.1892, test accuracy: 0.9471
# 270th iteration, training loss: 0.2690, test accuracy: 0.9427
# 280th iteration, training loss: 0.1628, test accuracy: 0.9500
# 290th iteration, training loss: 0.2874, test accuracy: 0.9397
# 300th iteration, training loss: 0.1705, test accuracy: 0.9546
# 310th iteration, training loss: 0.1944, test accuracy: 0.9454
# 320th iteration, training loss: 0.1927, test accuracy: 0.9387
# 330th iteration, training loss: 0.1302, test accuracy: 0.9392
# 340th iteration, training loss: 0.0987, test accuracy: 0.9591
# 350th iteration, training loss: 0.0954, test accuracy: 0.9583
# 360th iteration, training loss: 0.1769, test accuracy: 0.9534
# 370th iteration, training loss: 0.0602, test accuracy: 0.9581
# 380th iteration, training loss: 0.1035, test accuracy: 0.9520
# 390th iteration, training loss: 0.2149, test accuracy: 0.9526
# 400th iteration, training loss: 0.0487, test accuracy: 0.9547
# 410th iteration, training loss: 0.1248, test accuracy: 0.9616
# 420th iteration, training loss: 0.1579, test accuracy: 0.9553
# 430th iteration, training loss: 0.2235, test accuracy: 0.9610
# 440th iteration, training loss: 0.1792, test accuracy: 0.9447
# 450th iteration, training loss: 0.1040, test accuracy: 0.9509
# 460th iteration, training loss: 0.1066, test accuracy: 0.9638
# 470th iteration, training loss: 0.0626, test accuracy: 0.9647
# 480th iteration, training loss: 0.0734, test accuracy: 0.9633
# 490th iteration, training loss: 0.1224, test accuracy: 0.9658
# 500th iteration, training loss: 0.0861, test accuracy: 0.9545
# 510th iteration, training loss: 0.0715, test accuracy: 0.9535
# 520th iteration, training loss: 0.0667, test accuracy: 0.9651
# 530th iteration, training loss: 0.0724, test accuracy: 0.9644
# 540th iteration, training loss: 0.0422, test accuracy: 0.9674
# 550th iteration, training loss: 0.0867, test accuracy: 0.9603
# 560th iteration, training loss: 0.0830, test accuracy: 0.9685
# 570th iteration, training loss: 0.0332, test accuracy: 0.9700
# 580th iteration, training loss: 0.1242, test accuracy: 0.9652
# 590th iteration, training loss: 0.0816, test accuracy: 0.9568
# 600th iteration, training loss: 0.0889, test accuracy: 0.9515
# 610th iteration, training loss: 0.2116, test accuracy: 0.9636
# 620th iteration, training loss: 0.1690, test accuracy: 0.9566
# 630th iteration, training loss: 0.1493, test accuracy: 0.9675
# 640th iteration, training loss: 0.1789, test accuracy: 0.9701
# 650th iteration, training loss: 0.0379, test accuracy: 0.9675
# 660th iteration, training loss: 0.0790, test accuracy: 0.9680
# 670th iteration, training loss: 0.2746, test accuracy: 0.9700
# 680th iteration, training loss: 0.0567, test accuracy: 0.9666
# 690th iteration, training loss: 0.0423, test accuracy: 0.9656
# 700th iteration, training loss: 0.0993, test accuracy: 0.9680
# 710th iteration, training loss: 0.1079, test accuracy: 0.9741
# 720th iteration, training loss: 0.0276, test accuracy: 0.9736
# 730th iteration, training loss: 0.0591, test accuracy: 0.9733
# 740th iteration, training loss: 0.0706, test accuracy: 0.9698
# 750th iteration, training loss: 0.0328, test accuracy: 0.9698
# 760th iteration, training loss: 0.1631, test accuracy: 0.9787
# 770th iteration, training loss: 0.0739, test accuracy: 0.9759
# 780th iteration, training loss: 0.1051, test accuracy: 0.9762
# 790th iteration, training loss: 0.1361, test accuracy: 0.9644
# 800th iteration, training loss: 0.1002, test accuracy: 0.9696
# 810th iteration, training loss: 0.0636, test accuracy: 0.9692
# 820th iteration, training loss: 0.0349, test accuracy: 0.9706
# 830th iteration, training loss: 0.0235, test accuracy: 0.9716
# 840th iteration, training loss: 0.1687, test accuracy: 0.9710
# 850th iteration, training loss: 0.0296, test accuracy: 0.9743
# 860th iteration, training loss: 0.0749, test accuracy: 0.9743
# 870th iteration, training loss: 0.1436, test accuracy: 0.9672
# 880th iteration, training loss: 0.0303, test accuracy: 0.9746
# 890th iteration, training loss: 0.0646, test accuracy: 0.9629
# 900th iteration, training loss: 0.0185, test accuracy: 0.9745
# 910th iteration, training loss: 0.2666, test accuracy: 0.9632
# 920th iteration, training loss: 0.0466, test accuracy: 0.9757
# 930th iteration, training loss: 0.1107, test accuracy: 0.9726
# 940th iteration, training loss: 0.0220, test accuracy: 0.9768
# 950th iteration, training loss: 0.0837, test accuracy: 0.9760
# 960th iteration, training loss: 0.0384, test accuracy: 0.9758
# 970th iteration, training loss: 0.0705, test accuracy: 0.9732
# 980th iteration, training loss: 0.1046, test accuracy: 0.9759
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-86cfdf3deece> in <module>
#       9         _, loss, summary = sess.run([train_step, cross_entropy, merged], feed_dict={x: batch_x, y_true: batch_y})
#      10         train_writer.add_summary(summary, step)
# ---> 11         acc, summary = sess.run([accuracy, merged], feed_dict={x: test_data, y_true: test_label_hot})
#      12         test_writer.add_summary(summary, step)
#      13         if (step + 1) % 10 == 0:
#
# ~/jtkim/venv/py3-jupyter/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     898     try:
#     899       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 900                          run_metadata_ptr)
#     901       if run_metadata:
#     902         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/jtkim/venv/py3-jupyter/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1133     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1134       results = self._do_run(handle, final_targets, final_fetches,
# -> 1135                              feed_dict_tensor, options, run_metadata)
#    1136     else:
#    1137       results = []
#
# ~/jtkim/venv/py3-jupyter/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1314     if handle is None:
#    1315       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1316                            run_metadata)
#    1317     else:
#    1318       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/jtkim/venv/py3-jupyter/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1320   def _do_call(self, fn, *args):
#    1321     try:
# -> 1322       return fn(*args)
#    1323     except errors.OpError as e:
#    1324       message = compat.as_text(e.message)
#
# ~/jtkim/venv/py3-jupyter/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1305       self._extend_graph()
#    1306       return self._call_tf_sessionrun(
# -> 1307           options, feed_dict, fetch_list, target_list, run_metadata)
#    1308
#    1309     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~/jtkim/venv/py3-jupyter/lib/python3.6/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1407       return tf_session.TF_SessionRun_wrapper(
#    1408           self._session, options, feed_dict, fetch_list, target_list,
# -> 1409           run_metadata)
#    1410     else:
#    1411       with errors.raise_exception_on_not_ok_status() as status:
#
# KeyboardInterrupt:
